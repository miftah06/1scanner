# %% [markdown]
# <a href="https://colab.research.google.com/github/miftah06/1scanner/blob/master/1_scanner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt install python3
# !apt install dnsutils
# !apt install curl
# !apt install wget
# !apt install python3-pip
# !apt install unzipper
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python3 is already the newest version (3.8.2-0ubuntu2).
# python3 set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 13 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   bind9-dnsutils bind9-host bind9-libs libmaxminddb0
# Suggested packages:
#   mmdb-bin
# The following NEW packages will be installed:
#   bind9-dnsutils bind9-host bind9-libs dnsutils libmaxminddb0
# 0 upgraded, 5 newly installed, 0 to remove and 13 not upgraded.
# Need to get 1,314 kB of archives.
# After this operation, 4,190 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libmaxminddb0 amd64 1.4.2-0ubuntu1.20.04.1 [26.2 kB]
# ...

# %%
# !git clone https://github.com/miftah06/1scanner.git
# !cd 1scanner && pip3 install -r requirements.txt
# Out:
# fatal: destination path '1scanner' already exists and is not an empty directory.
# ...
#   Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# ...
#   Using cached tweepy-4.6.0-py2.py3-none-any.whl (69 kB)
# ...
#   Using cached pandas-1.1.5.tar.gz (5.2 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached emails-0.6-py2.py3-none-any.whl (56 kB)
# ...
#   Using cached numpy-1.19.5.zip (7.3 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# ...
#   Using cached sniffer-0.4.1-py2.py3-none-any.whl (22 kB)
# ...
#   Using cached networkx-2.5.1-py3-none-any.whl (1.6 MB)
# ...
#   Using cached pinject-0.14.1-py3-none-any.whl (42 kB)
# ...

# %%
# !pip3 install scapy
# !cd 1scanner && python3 scanner.py
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 25.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scapy: filename=scapy-2.5.0-py2.py3-none-any.whl size=1444325 sha256=c15bbdad5fead5ad6c6b2e62fe53a6f3f42fbfe95ac5a772e53da4a11cbfe84f
#   Stored in directory: /root/.cache/pip/wheels/82/b7/03/8344d8cf6695624746311bc0d389e9d05535ca83c35f90241d
# Successfully built scapy
# ...
#  Your target DNS:
